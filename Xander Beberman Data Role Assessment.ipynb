# %% [markdown]
# # Data Science and Public Policy RA Exercise
# ## Xander Beberman
#
# First ste

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
donations = pd.read_csv('data/donations.csv')

# %%
donations.head()
# Out:
#                          donationid                         projectid  \
# 0  431d720bc3dfd75ae445a5eaa0b0638d  ffffac55ee02a49d1abc87ba6fc61135
# 1  fcfedba1c8a0ba77d280cace80a909f6  ffffac55ee02a49d1abc87ba6fc61135
# 2  3fa95d29986aa6f401c6719ced3a3ce7  ffffac55ee02a49d1abc87ba6fc61135
# 3  020ad6bd5e88a35741d23b5e08f8b8e8  ffffac55ee02a49d1abc87ba6fc61135
# 4  4b44b03f304d6425ae94446686f93cd6  ffffac55ee02a49d1abc87ba6fc61135
#
#                        donor_acctid      donor_city donor_state  donor_zip  \
# 0  22cbc920c9b5fa08dfb331422f5926b5  Peachtree City          GA    30269.0
# 1  521f1830a77c9dbbf8119d99c6206a16             NaN          GA        NaN
# 2  1e0a63fc8141c7ba26b8b44ca0871b90       Rockville          MD    20853.0
# 3  1d4acb508df29d5f1cc6d382969576cb           Salem          IN    47167.0
# 4  59c3c3cfcccc53ae855f7eee911c478b       anonymous         NaN        0.0
#
#   is_teacher_acct       donation_timestamp  donation_to_project  \
# ...

# %%
donations.replace({'t':1, 'f':0}, inplace=True)

# %%
donations.describe()
# Out:
#           donor_zip  is_teacher_acct  donation_to_project  \
# count  1.385927e+06     3.097989e+06         3.097989e+06
# mean   5.066494e+04     1.158552e-01         6.594590e+01
# std    3.331468e+04     3.200512e-01         2.379026e+02
# min    0.000000e+00     0.000000e+00        -1.275000e+01
# 25%    2.000300e+04     0.000000e+00         1.000000e+01
# 50%    4.671400e+04     0.000000e+00         2.125000e+01
# 75%    8.952100e+04     0.000000e+00         5.000000e+01
# max    9.999900e+04     1.000000e+00         1.472040e+05
#
#        donation_optional_support  donation_total  \
# count               3.097989e+06    3.097989e+06
# mean                1.073131e+01    7.667691e+01
# std                 3.688343e+01    2.704941e+02
# min                -2.250000e+00   -1.500000e+01
# 25%                 1.500000e+00    1.000000e+01
# 50%                 3.750000e+00    2.500000e+01
# 75%                 7.500000e+00    5.611000e+01
# ...

# %%
# outputting count information
print('Column\t\t\tUnique values\tNA values')
for col in donations:
    print('{:21.21}\t{}\t\t{}'.format(donations[col].name, donations[col].nunique(), donations[col].isna().sum()))
# Out:
# Column			Unique values	NA values
# donationid           	3097989		0
# projectid            	525042		0
# donor_acctid         	1282092		0
# donor_city           	20461		2005612
# donor_state          	61		603109
# donor_zip            	23032		1712062
# is_teacher_acct      	2		0
# donation_timestamp   	3084243		0
# donation_to_project  	75834		0
# donation_optional_sup	23060		0
# donation_total       	84107		0
# dollar_amount        	3		0
# donation_included_opt	2		0
# payment_method       	8		0
# payment_included_acct	2		0
# payment_included_camp	2		0
# payment_included_web_	2		0
# payment_was_promo_mat	2		0
# via_giving_page      	2		0
# for_honoree          	2		0
# donation_message     	949772		797266

# %%
donations.hist(layout=(6,2), figsize=(8,24))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1641ded30>,
# ...
#       dtype=object)

# %% [markdown]
# For small categorical variables

# %%
fig = plt.figure(figsize=(12,6))
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)

ax1 = plt.subplot(grid[0,:])
ax2 = plt.subplot(grid[1,0])
ax3 = plt.subplot(grid[1,1:])

donations['donor_state'].value_counts().plot(kind='bar', ax=ax1, title='donor_state')
donations['dollar_amount'].value_counts().plot(kind='bar', ax=ax2, title='dollar_amount')
donations['payment_method'].value_counts().plot(kind='bar', ax=ax3, title='payment_method')

# %%
donations.hist(column='donation_total', figsize=(12,4), log=True, bins=25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10dbd5630>]],
#       dtype=object)

# %%
donations.hist(column='donation_total', range=(-10,25000), log=True, figsize=(12,4), bins=25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10e838710>]],
#       dtype=object)

# %% [markdown]
# Do the same thing for projects.csv

# %%
projects = pd.read_csv('data/projects.csv')
projects.head()
# Out:
#                           projectid                    teacher_acctid  \
# 0  316ed8fb3b81402ff6ac8f721bb31192  42d43fa6f37314365d08692e08680973
# 1  90de744e368a7e4883223ca49318ae30  864eb466462bf704bf7a16a585ef296a
# 2  32943bb1063267de6ed19fc0ceb4b9a7  37f85135259ece793213aca9d8765542
# 3  bb18f409abda2f264d5acda8cab577a9  2133fc46f951f1e7d60645b0f9e48a6c
# 4  24761b686e18e5eace634607acbcc19f  867ff478a63f5457eaf41049536c47cd
#
#                            schoolid  school_ncesid  school_latitude  \
# 0  c0e6ce89b244764085691a1b8e28cb81   6.362701e+10        36.576340
# 1  d711e47810900c96f26a5d0be30c446d   4.837020e+11        32.911179
# 2  665c3613013ba0a66e3a2a26b89f1b68   4.103270e+11        45.166039
# 3  4f12c3fa0c1cce823c7ba1df57e90ccb   3.600153e+11        40.641727
# 4  10179fd362d7b8cf0e89baa1ca3025bb   6.227100e+10        34.043939
#
#    school_longitude  school_city school_state  school_zip school_metro  \
# ...

# %%
projects.replace({'t':1, 'f':0}, inplace=True)
print('Column\t\t\tUnique values\tNA values')
for col in projects:
    print('{:21.21}\t{}\t\t{}'.format(projects[col].name, projects[col].nunique(), projects[col].isna().sum()))
# Out:
# Column			Unique values	NA values
# projectid            	664098		0
# teacher_acctid       	249555		0
# schoolid             	57004		0
# school_ncesid        	52213		42736
# school_latitude      	54449		0
# school_longitude     	54479		0
# school_city          	9007		0
# school_state         	52		0
# school_zip           	16619		4
# school_metro         	3		81908
# school_district      	9246		948
# school_county        	1702		17
# school_charter       	2		0
# school_magnet        	2		0
# school_year_round    	2		0
# school_nlns          	2		0
# school_kipp          	2		0
# school_charter_ready_	2		0
# teacher_prefix       	5		4
# teacher_teach_for_ame	2		0
# teacher_ny_teaching_f	2		0
# primary_focus_subject	27		39
# primary_focus_area   	7		39
# secondary_focus_subje	27		207893
# secondary_focus_area 	7		207893
# resource_type        	6		45
# poverty_level        	4		0
# grade_level          	4		9
# fulfillment_labor_mat	4		35082
# total_price_excluding	103926		0
# ...

# %%
projects.describe()
# Out:
#        school_ncesid  school_latitude  school_longitude     school_zip  \
# count   6.213620e+05    664098.000000     664098.000000  664094.000000
# mean    2.608577e+11        37.240948        -93.344760   52926.452644
# std     1.589754e+11         4.668155         17.761908   31193.738658
# min     1.000050e+10        18.249140       -176.634989     410.000000
# 25%     1.000230e+11        34.038082       -112.003213   27589.000000
# 50%     2.615730e+11        37.662476        -87.681219   50702.000000
# 75%     3.704720e+11        40.758827        -79.193091   85043.000000
# max     6.100009e+11        67.258157        -66.628036   99950.000000
#
#        school_charter  school_magnet  school_year_round    school_nlns  \
# count   664098.000000  664098.000000      664098.000000  664098.000000
# mean         0.086730       0.093766           0.049738       0.014969
# std          0.281439       0.291504           0.217404       0.121429
# ...

# %%
projects.hist(layout=(6,3), figsize=(12,24), bins=25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10f6f8320>,
# ...
#       dtype=object)

# %%
projects['poverty_level'].value_counts().plot(kind='bar', title='poverty_level')

# %%
resources = pd.read_csv('data/resources.csv')
resources.head()
# Out:
#                          resourceid                         projectid  \
# 0  8a1c1c45bc30d065061912fd9114fcf3  ffffc4f85b60efc5b52347df489d0238
# 1  015d2c4935c50427964a12dc3f584091  ffffac55ee02a49d1abc87ba6fc61135
# 2  26a02944b2f0c25f9abdeacca3ede3ee  ffff97ed93720407d70a2787475932b0
# 3  7fef1f92cb4447d18d599f69ea27e833  ffff97ed93720407d70a2787475932b0
# 4  8dccf77df25ee615bb1a68b98ba9d861  ffff97ed93720407d70a2787475932b0
#
#    vendorid                   vendor_name project_resource_type  \
# 0     430.0        Woodwind and Brasswind            Technology
# 1      82.0         Best Buy for Business            Technology
# 2     767.0  Lakeshore Learning Materials              Supplies
# 3     767.0  Lakeshore Learning Materials              Supplies
# 4     767.0  Lakeshore Learning Materials              Supplies
#
#                                            item_name item_number  \
# 0                      iPod nano 4th Gen 8GB (Black)  249995.001
# ...

# %%
print('Column\t\t\tUnique values\tNA values')
for col in resources:
    print('{:21.21}\t{}\t\t{}'.format(resources[col].name, resources[col].nunique(), resources[col].isna().sum()))
# Out:
# Column			Unique values	NA values
# resourceid           	3667217		0
# projectid            	663773		0
# vendorid             	356		108269
# vendor_name          	355		108296
# project_resource_type	6		196
# item_name            	689312		13711
# item_number          	656096		25820
# item_unit_price      	29354		13894
# item_quantity        	317		8310

# %%
fig = plt.figure(figsize=(8,4))
ax1, ax2 = fig.subplots(1,2)
resources['project_resource_type'].value_counts().plot(kind='bar', ax=ax1, title='project_resource_type')
resources['item_unit_price'].plot(kind='hist', bins=25, ax=ax2, log=True, title='item_unit_price')

# %%
resources['item_unit_price'].plot(kind='hist', bins=25, range=(0,500), title='item_unit_price histogram')

# %%
outcomes = pd.read_csv('data/outcomes.csv')
outcomes.head()
# Out:
#                           projectid is_exciting  \
# 0  ffffc4f85b60efc5b52347df489d0238           f
# 1  ffffac55ee02a49d1abc87ba6fc61135           f
# 2  ffff97ed93720407d70a2787475932b0           f
# 3  ffff418bb42fad24347527ad96100f81           f
# 4  ffff2d9c769c8fb5335e949c615425eb           t
#
#   at_least_1_teacher_referred_donor fully_funded at_least_1_green_donation  \
# 0                               NaN            f                       NaN
# 1                                 f            t                         t
# 2                                 f            t                         t
# 3                                 f            f                         t
# 4                                 t            t                         t
#
#   great_chat three_or_more_non_teacher_referred_donors  \
# 0          f                                       NaN
# 1          f                                         t
# ...

# %%
outcomes.replace({'t':1, 'f':0}, inplace=True)
print('Column\t\t\tUnique values\tNA values')
for col in outcomes:
    print('{:21.21}\t{}\t\t{}'.format(outcomes[col].name, outcomes[col].nunique(), outcomes[col].isna().sum()))
# Out:
# Column			Unique values	NA values
# projectid            	619326		0
# is_exciting          	2		0
# at_least_1_teacher_re	2		94398
# fully_funded         	2		0
# at_least_1_green_dona	2		94398
# great_chat           	2		0
# three_or_more_non_tea	2		94398
# one_non_teacher_refer	2		94398
# donation_from_thought	2		94398
# great_messages_propor	101		179839
# teacher_referred_coun	81		94398
# non_teacher_referred_	134		94398

# %%
outcomes.hist(figsize=(12,18), bins=25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12533e860>,
# ...
#       dtype=object)
