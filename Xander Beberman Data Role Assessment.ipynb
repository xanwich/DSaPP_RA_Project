# %% [markdown]
# # Data Science and Public Policy RA Exercise
# ## Xander Beberman
#
# First ste

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
donations = pd.read_csv('data/donations.csv')

# %%
donations.head()
# Out:
#                          donationid                         projectid  \
# 0  431d720bc3dfd75ae445a5eaa0b0638d  ffffac55ee02a49d1abc87ba6fc61135
# 1  fcfedba1c8a0ba77d280cace80a909f6  ffffac55ee02a49d1abc87ba6fc61135
# 2  3fa95d29986aa6f401c6719ced3a3ce7  ffffac55ee02a49d1abc87ba6fc61135
# 3  020ad6bd5e88a35741d23b5e08f8b8e8  ffffac55ee02a49d1abc87ba6fc61135
# 4  4b44b03f304d6425ae94446686f93cd6  ffffac55ee02a49d1abc87ba6fc61135
#
#                        donor_acctid      donor_city donor_state  donor_zip  \
# 0  22cbc920c9b5fa08dfb331422f5926b5  Peachtree City          GA    30269.0
# 1  521f1830a77c9dbbf8119d99c6206a16             NaN          GA        NaN
# 2  1e0a63fc8141c7ba26b8b44ca0871b90       Rockville          MD    20853.0
# 3  1d4acb508df29d5f1cc6d382969576cb           Salem          IN    47167.0
# 4  59c3c3cfcccc53ae855f7eee911c478b       anonymous         NaN        0.0
#
#   is_teacher_acct       donation_timestamp  donation_to_project  \
# ...

# %%
donations.replace({'t':1, 'f':0}, inplace=True)

# %%
donations.describe()
# Out:
#           donor_zip  is_teacher_acct  donation_to_project  \
# count  1.385927e+06     3.097989e+06         3.097989e+06
# mean   5.066494e+04     1.158552e-01         6.594590e+01
# std    3.331468e+04     3.200512e-01         2.379026e+02
# min    0.000000e+00     0.000000e+00        -1.275000e+01
# 25%    2.000300e+04     0.000000e+00         1.000000e+01
# 50%    4.671400e+04     0.000000e+00         2.125000e+01
# 75%    8.952100e+04     0.000000e+00         5.000000e+01
# max    9.999900e+04     1.000000e+00         1.472040e+05
#
#        donation_optional_support  donation_total  \
# count               3.097989e+06    3.097989e+06
# mean                1.073131e+01    7.667691e+01
# std                 3.688343e+01    2.704941e+02
# min                -2.250000e+00   -1.500000e+01
# 25%                 1.500000e+00    1.000000e+01
# 50%                 3.750000e+00    2.500000e+01
# 75%                 7.500000e+00    5.611000e+01
# ...

# %%
# outputting count information
print('Column\t\t\tUnique values\tNA values')
for col in donations:
    print('{:21.21}\t{}\t\t{}'.format(donations[col].name, donations[col].nunique(), donations[col].isna().sum()))
# Out:
# Column			Unique values	NA values
# donationid           	3097989		0
# projectid            	525042		0
# donor_acctid         	1282092		0
# donor_city           	20461		2005612
# donor_state          	61		603109
# donor_zip            	23032		1712062
# is_teacher_acct      	2		0
# donation_timestamp   	3084243		0
# donation_to_project  	75834		0
# donation_optional_sup	23060		0
# donation_total       	84107		0
# dollar_amount        	3		0
# donation_included_opt	2		0
# payment_method       	8		0
# payment_included_acct	2		0
# payment_included_camp	2		0
# payment_included_web_	2		0
# payment_was_promo_mat	2		0
# via_giving_page      	2		0
# for_honoree          	2		0
# donation_message     	949772		797266

# %%
donations.hist(layout=(6,2), figsize=(8,24))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1641ded30>,
# ...
#       dtype=object)

# %% [markdown]
# For small categorical variables

# %%
fig = plt.figure(figsize=(12,6))
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)

ax1 = plt.subplot(grid[0,:])
ax2 = plt.subplot(grid[1,0])
ax3 = plt.subplot(grid[1,1:])

donations['donor_state'].value_counts().plot(kind='bar', ax=ax1)
donations['dollar_amount'].value_counts().plot(kind='bar', ax=ax2)
donations['payment_method'].value_counts().plot(kind='bar', ax=ax3)

# %%
donations.hist(column='donation_total', figsize=(12,4), log=True, bins=25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10dbd5630>]],
#       dtype=object)

# %%
donations.hist(column='donation_total', range=(-10,25000), log=True, figsize=(12,4), bins=25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10e838710>]],
#       dtype=object)
